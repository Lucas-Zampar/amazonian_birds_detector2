# %% [markdown]
# Neste notebook, consta o código para anotar os frames de um vídeo por meio do modelo definitivo.

# %% [markdown]
# # Imports

# %%
import sys
import PIL
from project_utils.fo_dataset_pipeline import *
#from project_utils.draw_detections import *
from project_utils.draw_detections_en import *
import torch
# Out:
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/home/lucaszampar/mambaforge/envs/ICE2/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/home/lucaszampar/mambaforge/envs/ICE2/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lucaszampar/mambaforge/envs/ICE2/lib/python3.9/site-packages/fiftyone/core/uid.py", line 88, in send_import_event
#     tracker.send(
#   File "/home/lucaszampar/mambaforge/envs/ICE2/lib/python3.9/site-packages/universal_analytics/tracker.py", line 172, in send
#     return self.http.send(data)
#   File "/home/lucaszampar/mambaforge/envs/ICE2/lib/python3.9/site-packages/universal_analytics/requests.py", line 65, in send
#     self.session.post(self.endpoint, data=payload)
#   File "/home/lucaszampar/mambaforge/envs/ICE2/lib/python3.9/site-packages/httpx/_client.py", line 1132, in post
#     return self.request(
# ...

# %%
from tqdm import trange

# %% [markdown]
# # Carregando o modelo

# %%
# caminho para o modelo definitivo
#model_path = '../faster_rcnn/final_test/model_0/mmdet.faster_rcnn_resnext101_32x4d_fpn_1x.pth'

model_path = '../faster_rcnn/new_paper_2024/model_1/mmdet.faster_rcnn_resnext101_32x4d_fpn_1x.pth'

# carrega o modelo 
model_type, model, img_size, class_map = get_model_from_checkpoint(model_path)

# define a lista de transformações na imagem para inferência pelo modelo conforme os parâmetros de treinamento
infer_tfms = get_tfms(img_size=img_size, tfms_type = 'valid')

device = torch.device('cuda')

model.to(device)
# Out:
# load checkpoint from local path: ../faster_rcnn/new_paper_2024/model_1/mmdet.faster_rcnn_resnext101_32x4d_fpn_1x.pth
# /home/lucaszampar/mambaforge/envs/ICE2/lib/python3.9/site-packages/mmdet/core/anchor/builder.py:16: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   warnings.warn(
# 2024-07-13 19:03:44,445 - mmcv - INFO - initialize ResNeXt with init_cfg {'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnext101_32x4d'}
# 2024-07-13 19:03:44,446 - mmcv - INFO - load model from: open-mmlab://resnext101_32x4d
# 2024-07-13 19:03:44,446 - mmcv - INFO - load checkpoint from openmmlab path: open-mmlab://resnext101_32x4d
# 2024-07-13 19:03:44,570 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2024-07-13 19:03:44,585 - mmcv - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# ...

# %% [markdown]
# # Carregando o Vídeo

# %%
# solicita o nome de arquivo do vídeo
video_filename = input('Por favor, digite o caminho do arqivo de vídeo: ')

# define o nome do novo arquivo de vídeo com os frames anotados
new_video_filename = f'annotated_video.mp4'

# inicia a captura de vídeo
video = cv2.VideoCapture(video_filename)

# verifica se o vídeo abriu corretamente
if video.isOpened() == False:
    # caso não tenha aberto, encerra o programa
    print('Erro ao abrir arquivo!')
    sys.exit() 

# defina a largura e altura dos frames
frame_width = int(video.get(3))
frame_height = int(video.get(4))

# define o codec (no caso, será MP4, mas podem ser outros)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# writer para novo vídeo
new_video = cv2.VideoWriter(new_video_filename, fourcc, 10, (frame_width, frame_height))
# Out:
# Por favor, digite o caminho do arqivo de vídeo: 03062024_082456_083456.mp4

# %% [markdown]
# # Anotando o Vídeo

# %%
# número total de frames
total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

print('Iniciando a escrita dos frames ...')

for _ in trange(total_frames):
    # lê o próximo frame
    ret, frame = video.read()

    if ret == True: 
        # converte de BGR para RGB
        pil_array = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # converte array em objeto PIL
        pil_frame = PIL.Image.fromarray(pil_array)

        # inferência
        preds = model_type.end2end_detect(pil_frame, infer_tfms, model, class_map=class_map, detection_threshold=0.5)
        
        # anota a frame
        new_frame = draw_bb(frame, preds)

        # salva o frame
        new_video.write(new_frame)
        
    else: 
        # caso não haja mais frames válidos para ler, encerre o laço
        break
# Out:
# Iniciando a escrita dos frames ...
#   0%|                                                  | 0/6000 [00:00<?, ?it/s]/home/lucaszampar/mambaforge/envs/ICE2/lib/python3.9/site-packages/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /home/lucaszampar/mambaforge/envs/ICE2/lib/python3.9/site-packages/mmdet/core/anchor/anchor_generator.py:360: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   warnings.warn(
# 100%|███████████████████████████████████████| 6000/6000 [13:36<00:00,  7.35it/s]

# %% [markdown]
# # Salvando o Vídeo

# %%
video.release()
new_video.release()
